# %%
words = []
f = open("words.txt",'r')
lines = f.readlines()
for line in lines:
    words.append(line)
print(words)
# Out:
# ['zoo,768\n', 'zones,1168\n', 'zone,2553\n', 'zimbabwe,658\n', 'zero,2286\n', 'zealand,2636\n', 'zambia,732\n', 'z,1142\n', 'yugoslavia,1400\n', 'youths,914\n', 'youth,5415\n', 'yourself,10746\n', 'yours,4241\n', 'your,138337\n', 'youngsters,1749\n', 'youngest,1204\n', 'younger,5403\n', 'young,33611\n', 'you,695595\n', 'yorkshire,4393\n', 'york,9906\n', 'yo,1206\n', 'yields,940\n', 'yield,2113\n', 'yet,33752\n', 'yesterday,19507\n', 'yes,60612\n', 'yer,1509\n', 'yep,1317\n', 'yeltsin,1192\n', 'yellow,4557\n', 'yelled,754\n', 'years,90224\n', 'year,73778\n', 'yeah,83382\n', 'ye,1700\n', 'yarn,877\n', 'yards,3678\n', 'yard,3267\n', 'yacht,1033\n', 'ya,1753\n', 'y,3906\n', 'x,6741\n', 'wycliffe,716\n', 'wrote,9909\n', 'wrong,16080\n', 'written,13675\n', 'writings,1063\n', 'writing,11582\n', 'writes,2607\n', 'writers,3581\n', 'writer,3742\n', 'write,10882\n', 'wrist,1056\n', 'wright,1972\n', 'wrapped,1723\n', 'wounds,1025\n', 'wounded,1692\n', 'wound,2161\n', 'would-be,783\n', 'would,255
# ...

# %%
words = [line.strip() for line in open("words.txt", 'r')]
# map , reduce
k = list(map(lambda x: [x.split(',')[0],int(x.split(',')[1])], words))
print(k)
# Out:
# [['zoo', 768], ['zones', 1168], ['zone', 2553], ['zimbabwe', 658], ['zero', 2286], ['zealand', 2636], ['zambia', 732], ['z', 1142], ['yugoslavia', 1400], ['youths', 914], ['youth', 5415], ['yourself', 10746], ['yours', 4241], ['your', 138337], ['youngsters', 1749], ['youngest', 1204], ['younger', 5403], ['young', 33611], ['you', 695595], ['yorkshire', 4393], ['york', 9906], ['yo', 1206], ['yields', 940], ['yield', 2113], ['yet', 33752], ['yesterday', 19507], ['yes', 60612], ['yer', 1509], ['yep', 1317], ['yeltsin', 1192], ['yellow', 4557], ['yelled', 754], ['years', 90224], ['year', 73778], ['yeah', 83382], ['ye', 1700], ['yarn', 877], ['yards', 3678], ['yard', 3267], ['yacht', 1033], ['ya', 1753], ['y', 3906], ['x', 6741], ['wycliffe', 716], ['wrote', 9909], ['wrong', 16080], ['written', 13675], ['writings', 1063], ['writing', 11582], ['writes', 2607], ['writers', 3581], ['writer', 3742], ['write', 10882], ['wrist', 1056], ['wright', 1972], ['wrapped', 1723], ['wounds', 1025], ['wou
# ...

# %%
k = [line.strip() for line in open('words.txt','r')]
words = list(map(lambda x: [(x.split(',')[0]),(x.split(',')[1])], k))
words.sort(key = lambda x: x[1],reverse = True)
print(words)
# Out:
# [['richard', '9996'], ['in_terms_of', '9993'], ['threshold', '999'], ['stirling', '999'], ['lanes', '999'], ['jacques', '999'], ['infrastructure', '999'], ['greenhouse', '999'], ['fruits', '999'], ['copyright', '999'], ['combining', '999'], ['bucket', '999'], ['bankruptcy', '999'], ['aloud', '999'], ['is', '998867'], ['a_lot', '9985'], ['response', '9984'], ['tubes', '998'], ['harrison', '998'], ['freezing', '998'], ['majority', '9972'], ['degree', '9972'], ['satisfying', '997'], ['rebellion', '997'], ['dawson', '997'], ['colonies', '997'], ['associates', '997'], ['100000', '997'], ['ulcer', '996'], ['sunny', '996'], ['reservations', '996'], ['nuisance', '996'], ['intervene', '996'], ['hit', '9953'], ['effective', '9951'], ['get', '99506'], ['shells', '995'], ['saints', '995'], ['meredith', '995'], ['holly', '995'], ['fraser', '995'], ['defended', '995'], ['v', '9948'], ['scottish', '9941'], ['prestige', '994'], ['insists', '994'], ['disappointing', '994'], ['constructive', '994'], [
# ...

# %%
'''
def draw_chart(X,Y,slope, intercept, x_col):
    fig = plt.figure()
    fig.suptitle('Linear Regresion for Class data')
    ax = fig.add_subplot(111)
    ax.set_xlabel(x_col)
    ax.set_ylabel('GPA')
    
    plt.scatter(X, Y)
    
    min_X = min(X)
    max_X = max(X)
    min_Y = min_X * slope + intercept
    max_Y = max_X * slope + intercept
    plt.plot([min_X, max_X], [min_Y, max_y],
            color = 'red',
            linestyle = '--',
            linewidth = 3.0)
    
    ax.text(min_X, min_Y + 0.1, r'$y = %.21fx + %.21f$' %(slope,
                                                         intercept),
           fontsize = 15)
    
    plt.savefig('chart.svg')
  '''
# Out:
# "\ndef draw_chart(X,Y,slope, intercept, x_col):\n    fig = plt.figure()\n    fig.suptitle('Linear Regresion for Class data')\n    ax = fig.add_subplot(111)\n    ax.set_xlabel(x_col)\n    ax.set_ylabel('GPA')\n    \n    plt.scatter(X, Y)\n    \n    min_X = min(X)\n    max_X = max(X)\n    min_Y = min_X * slope + intercept\n    max_Y = max_X * slope + intercept\n    plt.plot([min_X, max_X], [min_Y, max_y],\n            color = 'red',\n            linestyle = '--',\n            linewidth = 3.0)\n    \n    ax.text(min_X, min_Y + 0.1, r'$y = %.21fx + %.21f$' %(slope,\n                                                         intercept),\n           fontsize = 15)\n    \n    plt.savefig('chart.svg')\n  "

# %%
fig = plt.figure()

fig.suptitle('Frequency of Words')
fig.add_subplot(111)
ax.set_xlabel('rank_words')
ax.set_ylabel('Freq')


X = words[:,0]
Y = words[:,1]

plt.scatter(X, Y)

min_X = min(X)
print(min_X)
max_X = max(X)
min_Y = min_X * slope + intercept
max_Y = max_X * slope + intercept
plt.plot([min_X max_X], [min_Y, max_Y], color = 'green', linestyle = '--', linewidth = 2.0)

ax.text(min_X, min_Y + 0.1, r'$y = %.21fx + %.21f$' %(slope, intercept), fontsize = 15)
# Out:
#   File "<ipython-input-11-75b740aa8618>", line 19
#     plt.plot([min_X max_X], [min_Y, max_Y], color = 'green', linestyle = '--', linewidth = 2.0)
#                         ^
# SyntaxError: invalid syntax

# %%
k = [line.strip() for line in open('words.txt','r')]
count_words = list(map(lambda x: int(x.split(',')[1]), k))
count_words.sort(key = lambda x: x[1],reverse = True)
return words
